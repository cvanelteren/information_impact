# %%
f
# Out:
# [<matplotlib.lines.Line2D object at 0x7f595dd1f5f8>, <matplotlib.lines.Line2D object at 0x7f595dd1f4a8>]
# /home/casper/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
