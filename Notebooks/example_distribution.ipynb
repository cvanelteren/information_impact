# %%
from matplotlib import style
style.use('seaborn-poster')
import numpy as np, matplotlib.pyplot as plt

from scipy.stats import norm

x  = np.linspace(-7, 7, 1000)
y  = norm.pdf(x - 1)
y += norm.pdf(x-4.5) / 2
y += norm.pdf(x+2) / 3

fig, ax = plt.subplots()
ax.plot(x, y)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.spines['left'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

ax.set_ylabel('$P(S)$', fontsize = 50)
ax.set_xlabel('$S$', fontsize = 50)
ax.set_yticklabels([])
ax.set_xticklabels([])
fig.show()

fig.savefig('../../thesis/figures/example_distribution.png', \
            transparent=True, pad_inches = 0, bbox_inches = 'tight')
# Out:
# /home/casper/miniconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
