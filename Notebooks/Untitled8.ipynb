# %%
from scipy import stats
import matplotlib.pyplot as plt, numpy as np

xr = np.arange(0, 10)

p  = np.linspace(0, 1, 10)


bino = stats.binom.pmf(xr, n = 10, p = p)

fig, ax = plt.subplots()
ax.plot(xr, p)
stats.
