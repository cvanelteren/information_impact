# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../')

import matplotlib.pyplot as plt, numpy as np, bokeh
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Models.fastIsing import Ising
import networkx as nx
g     = nx.grid_2d_graph(50, 50)
model = Ising(g)

temps    = np.linspace(0, 10, 20)
mag, sus = model.matchMagnetization()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Computing mag per t
# 100%|██████████| 20/20 [00:08<00:00,  2.29it/s]

# %%
from bokeh.plotting import figure, show
from bokeh.models import LinearAxis, Range1d
from bokeh.io import output_notebook
output_notebook()

fig = figure(plot_width = 500,
             plot_height = 500)



fig.extra_y_ranges = dict(Magnetization   = Range1d(mag.min(), mag.max()),\
                          Susceptibility = Range1d(sus.min(), sus.max()),\
                         )

fig.add_layout(LinearAxis(y_range_name = 'Susceptibility'), 'right')
# fig.add_layout(LinearAxis(y_range_name = "Magnetization"), 'left')
fig.y_range = Range1d(0, 1)
fig.line(temps, mag, y_range_name = "Magnetization")
fig.line(temps, sus, y_range_name = 'Susceptibility')

show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="19934">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="39ba8b77-f55c-4d11-a430-a2503552d50d" data-root-id="19935"></div>

# %%
fig.y_range.__dict__
# Out:
# {'_id': '14770',
#  '_document': <bokeh.document.document.Document at 0x7f06900f1cc0>,
#  '_temp_document': None,
#  '_event_callbacks': {},
#  '_callbacks': {},
#  '_property_values': {},
#  '_unstable_default_values': {'renderers': [],
#   'callback': None,
#   'js_event_callbacks': {},
#   'js_property_callbacks': {}},
#  '_unstable_themed_values': {}}
